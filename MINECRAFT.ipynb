# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
#First, let's load in our Players and Sessions Dataset
players_data <- read_csv("players.csv")
players_data

sessions_data <- read_csv("sessions.csv")
sessions_data
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# 25  Amateur     TRUE
# ...

# %%
players_summary <- summary(players_data)
players_summary

players_experience <- unique(players_data$experience)
players_experience

players_gender <- unique(players_data$gender)
players_gender

sessions_summary <- summary(sessions_data)
sessions_summary
# Out:
#   experience        subscribe       hashedEmail         played_hours
#  Length:196         Mode :logical   Length:196         Min.   :  0.000
#  Class :character   FALSE:52        Class :character   1st Qu.:  0.000
#  Mode  :character   TRUE :144       Mode  :character   Median :  0.100
#                                                        Mean   :  5.846
#                                                        3rd Qu.:  0.600
#                                                        Max.   :223.100
#
#      name              gender               Age
#  Length:196         Length:196         Min.   : 9.00
#  Class :character   Class :character   1st Qu.:17.00
#  Mode  :character   Mode  :character   Median :19.00
#                                        Mean   :21.14
#                                        3rd Qu.:22.75
#                                        Max.   :58.00
#                                        NA's   :2
# ...

# %% [markdown]
# ______________________________________________________________________________
# In the Players Dataset, there are 7 variables and 196 observations.
#
# **Variable Meaning for Players Data set**
#
# **experience:** A player’s experience level with the game. One of “Pro”, “Veteran”, “Amateur”, “Regular”, or “Beginner”.
# Data type of **experience** is **Character**
#
# **subscribe:** Whether or not a player owns a paid subscription.
# Data type of **subscribe** is **Logical**
#
# **hashedEmail:** Player’s email
# Data type of **hashedEmail** is **Character**
#
# **played_hours:** Total Hours played.
# Data type of **played_hours** is **Double**
#
# **name:** Player’s name
# Data type of **name** is **Character**
#
# **gender:** Gender of the player. One of “Male”, “Female”, “Non-binary”, “Prefer not to say”, “Agender”, “Two-spirited”, or “Other”.
# Data type of **gender** is **Character**
#
# **Age:** Player’s age in Years.
# Data type of **Age** is **Double**
# _____________________________________________________________________________
# In the Sessions Dataset, there are 5 variables and 196 observations.
#
# **Variable Meaning for Sessions Data set**
#
# **hashedEmail:** Player's email.
# Data type of **hashedEmail** is **Character**
#
# **start_time:** The time that a player began their gaming session.
# Data type of **start_time** is **Character**
#
# **end_time:** The time that a player concluded their gaming session.
# Data type of **end_time** is **Character**
#
# **original_start_time:** The time that a player began their gaming session in milliseconds.
# Data type of **original_start_time** is **Double**
#
# **original_end_time:** The time that a player concluded their gaming session in milliseconds.
# Data type of **original_end_time** is **Double**
# _____________________________________________________________________________

# %%
#Let's find the summary statistics
# of both the numeric variables
# of the players and sessions datasets

player_means <- players_data |>
select(played_hours, Age) |>
map_dfr(mean, na.rm = TRUE) |>
round(2)

player_means

session_means <- sessions_data |>
select(original_start_time, original_end_time) |>
map_dfr(mean, na.rm = TRUE) |>
round(2)

session_means
# Out:
#   played_hours Age
# 1 5.85         21.14
#   original_start_time original_end_time
# 1 1.719201e+12        1.719196e+12

# %% [markdown]
# The data was collected by a Computer Science Group at UBC, led by Frank Wood.
# They set up a Minecraft server where the players’ actions are recorded as they play.
# The hashedEmail variable is not useful in answering any question, so it will be culled.
# There are also some NA values in the age variable, so we would have to keep that fact in mind if we were to use the age variable.
# In this dataset, I am making the assumption that the data collected from these individuals is relatively truthful.
# _____________________________________________________________________________
#
# The broad question that I will address is: What “kinds” of players are more likely to contribute a large amount of data?
# To answer this broad question, I will pose the question:
# Which category in the variable experience contributes the most average played hours (AKA data)?
# To answer this specific question, I will need the variables in the players dataset, and I will not need to access any data within the sessions dataset, so I will not be wrangling the sessions dataset. Within the players dataset, I will first need to use the group_by() function to aggregate the data and group the unique categories in the experience variable, and use summarize to find the average hours played within each category. Since I am comparing each category by its amount/size, I will be using a bar graph.

# %%
#The Player dataset is already tidy since each variable is a single column, each observation is a single row, and each value is in a single
# cell. The variables that are irrelevant to us in this dataset are the hashedEmail and name column, as they do not help predict anything, 
# so we will cull
# that column
# I will also change the Data type of Age to Integer, because Age is not generally a decimal.

players_cull <- select(players_data, -hashedEmail, -name) |>
mutate(Age = as.integer(Age))
players_cull
# Out:
#     experience subscribe played_hours gender            Age
# 1   Pro         TRUE     30.3         Male               9
# 2   Veteran     TRUE      3.8         Male              17
# 3   Veteran    FALSE      0.0         Male              17
# 4   Amateur     TRUE      0.7         Female            21
# 5   Regular     TRUE      0.1         Male              21
# 6   Amateur     TRUE      0.0         Female            17
# 7   Regular     TRUE      0.0         Female            19
# 8   Amateur    FALSE      0.0         Male              21
# 9   Amateur     TRUE      0.1         Male              47
# 10  Veteran     TRUE      0.0         Female            22
# 11  Veteran     TRUE      1.6         Female            23
# 12  Pro         TRUE      0.0         Male              17
# 13  Beginner    TRUE      1.5         Female            25
# 14  Amateur     TRUE      0.2         Male              22
# 15  Veteran     TRUE      0.0         Non-binary        17
# ...

# %%
#From here let's explore the relationship between the exploratory variables (experience, subscribe, gender and Age) and Play Time.
#First let's see if there is a relationship between played_hours and Age.

hours_vs_age <- ggplot(players_cull, aes(x = Age, y = played_hours)) +
geom_point() +
scale_y_continuous(trans = 'log10') +
labs(x = "Age of Player in Years", y = "Hours played in Total by Player (scaled by log10)") +
ggtitle("Age of Player vs Hours played in Total by Player")

hours_vs_age
# Out:
# Warning message in scale_y_continuous(trans = "log10"):
# “log-10 transformation introduced infinite values.”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#From the scatterplot above, we see that there are some people with 0 hours played. Since it makes the plot
# less readable paired with the fact that players with 0 hours played does not help predict, so I will filter out the 
# players with 0 hours played

filter_hours_vs_age <- players_cull |>
filter(played_hours > 0) |>
ggplot(aes(x = Age, y = played_hours)) +
geom_point() +
scale_y_continuous(trans = 'log10') +
labs(x = "Age of Player in Years", y = "Hours played in Total by Player (scaled by log10)") +
ggtitle("Age of Player vs Hours played in Total by Player")

filter_hours_vs_age
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#Now that we have an exploratory scatter plot, we can use the other non-numeric variables like experience, gender and subscribe to see if
# they contribute to the trend

experience_filter_hours_vs_age <- filter_hours_vs_age + aes(colour = experience)
experience_filter_hours_vs_age
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
# The scatterplot above is messy, we are unable to discern any trends within a certain colour. Let's instead use a histogram to
# examine the trends of age vs hours played as seperate graphs per category in experience


players_experience_graphs <- experience_filter_hours_vs_age +
facet_wrap(~ as_factor(experience))

players_experience_graphs
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#Now let's see if there is a correlation between subscribers and the age vs played hours graph

subscriberes_filter_hours_vs_age <- filter_hours_vs_age + aes(colour = subscribe)
subscriberes_filter_hours_vs_age
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#Now that we have our tidy dataset, let's see if the variable experience correlates to more
# played hours

average_experience_hours <- players_cull |>
group_by(experience) |>
summarize(average_hours = round(mean(played_hours, na.rm = TRUE), 2),
         total_hours = sum(played_hours, na.rm = TRUE)) |>
arrange(average_hours)

average_experience_hours
# Out:
#   experience average_hours total_hours
# 1 Veteran     0.65          31.1
# 2 Beginner    1.25          43.7
# 3 Pro         2.60          36.4
# 4 Amateur     6.02         379.1
# 5 Regular    18.21         655.5

# %%
#At first glance, it looks like regular players overwhelm the results by a long shot, but first,
# Let's look at the ratio of experienced players to see if the result was due to regular being
# the majority experience of players

experience_number_players <- players_cull |>
group_by(experience) |>
summarize(count = n()) |>
arrange(count)

experience_number_players
# Out:
#   experience count
# 1 Pro        14
# 2 Beginner   35
# 3 Regular    36
# 4 Veteran    48
# 5 Amateur    63

# %%
#From the data frame above, it shows that the average kind of players make up the majority of the dataset
# Every other category is approximately even except Pro and Amateur.
#Let's graph the Experience against average_hours in a bar graph

experience_vs_hours_plot <- average_experience_hours |>
ggplot(aes(x=fct_reorder(experience, average_hours, .desc = TRUE), y=average_hours, fill = experience)) +
geom_bar(stat = "identity") +
labs(x = "Player Experience Level", y = "Average hours played", fill = "Experience Level") +
ggtitle("Relationship between type of player and average hours played")

experience_vs_hours_plot
# Out:
# plot without title
